# %% [markdown]
# # Spark Syntax
#
# On this laptop I have installed PySpark using anaconda. The goal is to demo the set up of a quick delta dataset that will have features like version history
#
# The data used in this example is taken from Kaggle here: https://www.kaggle.com/zynicide/wine-reviews

# %% [markdown]
# ## Initiate Spark
#
# This demo uses PySpark, but in the future the standalone writer will be available. At that point you could run this purely in python
# If this is released i will create a python notebook as well

# %%
# !rmdir /s /q "C:\Spark\data\wine\wine_delta\".
# Out:
# The system cannot find the file specified.

# %%
import pyspark
from delta import *

builder = pyspark.sql.SparkSession.builder.appName("MyApp") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %% [markdown]
# ## Create a Schema
# As we want to use a streaming way of reading in the data, we need to define a schema. In this example i will simply load the data using the regular Batch method with `infer_schema` set tot True. This schema is used for the stream

# %%
df = spark.read.csv(header=True, path='../rawdata/wine/wine.csv', inferSchema=True)
inferred_schema = df.schema
df.printSchema()
# Out:
# root
#  |-- country: string (nullable = true)
#  |-- points: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- province: string (nullable = true)
#  |-- region_1: string (nullable = true)
#  |-- region_2: string (nullable = true)
#  |-- taster_name: string (nullable = true)
#  |-- taster_twitter_handle: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- variety: string (nullable = true)
#  |-- winery: string (nullable = true)

# %%
df.toPandas().head(5)
# Out:
#   country  points  price           province           region_1  \
# 0   Italy      88   41.0  Sicily & Sardinia               Etna
# 1      US      88   60.0             Oregon  Willamette Valley
# 2  France      88   26.0   Southwest France          Montravel
# 3  France      88   25.0   Southwest France          Montravel
# 4  France      88   16.0       Loire Valley             Quincy
#
#             region_2   taster_name taster_twitter_handle  \
# 0               None          None                  None
# 1  Willamette Valley  Paul Gregutt           @paulgwine
# 2               None    Roger Voss            @vossroger
# 3               None    Roger Voss            @vossroger
# 4               None    Roger Voss            @vossroger
#
#                                                title  \
# 0                Benanti 2005 Il Monovitigno  (Etna)
# 1  Benton-Lane 2006 First Class Pinot Noir (Willa...
# 2  Château Puy-Servain 2003 Vieilles Vignes  (Mon...
# 3   Château Puy-Servain 2007 Marjolaine  (Montravel)
# 4              Domaine Philippe Portier 2007  Quincy
#
#                       variety                    winery
# 0           Nerello Mascalese                   Benanti
# 1                  Pinot Noir               Benton-Lane
# 2    Bordeaux-style Red Blend       Château Puy-Servain
# 3  Bordeaux-style White Blend       Château Puy-Servain
# 4             Sauvignon Blanc  Domaine Philippe Portier

# %%
## Create the Stream to read in the Raw Data
# In the following section we will read in the data from the wine_source folder. This

# %%
source_path = '../rawdata/wine/wine_source'
sink_path = "../data/wine/wine_delta"

# %%
# GJ: TODO ADD BASH COMMAND TO REMOVE FILES IN WINE_SOURCE, WINE_DELTA
! del "C:\Spark\rawdata\wine\wine_source\wine_new.csv"
! del "C:\Spark\rawdata\wine\wine_source\wineupdate.csv"

# %%
data = (spark
        .readStream
        .format("csv")
        .option("header", True)
        .schema(inferred_schema)
        .load(source_path)
       )
data
# Out:
# DataFrame[country: string, points: int, price: double, province: string, region_1: string, region_2: string, taster_name: string, taster_twitter_handle: string, title: string, variety: string, winery: string]

# %%
saveloc = sink_path
streamQuery = (data
              .writeStream
              .format('delta')
              .option('checkpointLocation', f"{saveloc}/_checkpoint")
              .trigger(once=True)
              .start(saveloc)
              )

# %%
streamQuery.recentProgress
# Out:
# [{'id': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e',
#   'runId': '7bb58882-1339-4592-b20a-5948da2443cb',
#   'name': None,
#   'timestamp': '2021-11-10T18:26:03.347Z',
#   'batchId': 0,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 5430,
#    'getBatch': 24,
#    'queryPlanning': 14,
#    'triggerExecution': 6222},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/C:/Spark/rawdata/wine/wine_source]',
#     'startOffset': None,
#     'endOffset': {'logOffset': 0},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[../data/wine/wine_delta]',
#    'numOutputRows': -1}}]

# %% [markdown]
# ## What did we do
# We ran a Streamquery that inserted the data in a delta table, from source to target. Using the recentProgress we can see that
# 117969 records were inserted into the delta table.
#
# We can now move forward with our analysis. Below i am loading this data using the regular batch way. We can see it is a regular dataframe and can use it as we want

# %%
df = (spark
     .read
     .format('delta')
     .load(sink_path))

# %%
unique_key = ['taster_name', 'title']

# %%
df.count()
# Out:
# 117969

# %% [markdown]
# ## More data
#
# We receive more data for our analysis. Let's say that a new month of observations is to be added. We want to keep track of the new data
# but also do not want additional work to incorporate this new data. This is streaming to the rescue!

# %%
# add wine_new.csv to Rawdata repo
# !copy "C:\Spark\rawdata\wine\wine_new.csv" "C:\Spark\rawdata\wine\wine_source\wine_new.csv"
# Out:
#         1 file(s) copied.

# %%
saveloc = sink_path
streamQuery = (data
              .writeStream
              .format('delta')
              .option('checkpointLocation', f"{saveloc}/_checkpoint")
              .trigger(once=True)
              .start(saveloc)
              )

# %%
streamQuery.recentProgress
# Out:
# [{'id': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e',
#   'runId': 'da168ca5-5ad2-427f-ba8e-cd3b42d9418a',
#   'name': None,
#   'timestamp': '2021-11-10T18:26:49.143Z',
#   'batchId': 1,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 140.98406880022557,
#   'durationMs': {'addBatch': 4810,
#    'getBatch': 18,
#    'latestOffset': 798,
#    'queryPlanning': 15,
#    'triggerExecution': 7093,
#    'walCommit': 779},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/C:/Spark/rawdata/wine/wine_source]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 1},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 140.98406880022557}],
#   'sink': {'description': 'DeltaSink[../data/wine/wine_delta]',
#    'numOutputRows': -1}}]

# %%
df = (spark
     .read
     .format('delta')
     .load(sink_path))

# %%
df.count()
# Out:
# 118969

# %% [markdown]
# ## What happened?
#
# We reran the streaming query and it remembered that it already processed the 118969 lines and now online added the 1k lines
#
# This is very helpful if you expected to receive more updates as data becomes available

# %% [markdown]
# ## Delta Table
# As we inserted the data into a delta table we now have more options available
#
# First of all there is the history of the delta table. It will show what versions have existed and we can call them as required. To do that:

# %%
import delta.tables as dtables
delta_df = dtables.DeltaTable.forPath(spark, sink_path)

# %%
history = delta_df.history().take(5)
for row in history:
    print(row)
# Out:
# Row(version=1, timestamp=datetime.datetime(2021, 11, 10, 19, 26, 51, 570000), userId=None, userName=None, operation='STREAMING UPDATE', operationParameters={'epochId': '1', 'outputMode': 'Append', 'queryId': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e'}, job=None, notebook=None, clusterId=None, readVersion=0, isolationLevel=None, isBlindAppend=True, operationMetrics={'numOutputRows': '1000', 'numRemovedFiles': '0', 'numAddedFiles': '1', 'numOutputBytes': '61230'}, userMetadata=None)
# Row(version=0, timestamp=datetime.datetime(2021, 11, 10, 19, 25, 58, 639000), userId=None, userName=None, operation='STREAMING UPDATE', operationParameters={'epochId': '0', 'outputMode': 'Append', 'queryId': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e'}, job=None, notebook=None, clusterId=None, readVersion=None, isolationLevel=None, isBlindAppend=True, operationMetrics={'numOutputRows': '117969', 'numRemovedFiles': '0', 'numAddedFiles': '5', 'numOutputBytes': '5298445'}, userMetadata=None)

# %% [markdown]
# We see that two versions exists with both a timestamp, version and numOutputrows showing what actually happened. To actually load a particular version use:

# %%
# df1 = spark.read.format("delta").option("timestampAsOf", timestamp_string).load(sink_path)
# df2 = spark.read.format("delta").option("versionAsOf", version).load(sink_path)

# %% [markdown]
# # Updates
# This above works great as more data is added. What can also occur is that you receive updates that actually change existing data. Let's say that the Reviewscore was incorrectly calculated for a 500 reviews. This bug has been resolved and now we want to update our data. However, we do not want to lose our earlier work and be unable to reprocess the old models. This is possible in our current setup using the following change:

# %%
# move the 500 changed reviews into the Rawdata folder
# !copy "C:\Spark\rawdata\wine\wineupdate.csv" "C:\Spark\rawdata\wine\wine_source\wineupdate.csv"
# Out:
#         1 file(s) copied.

# %%
def merge_function(new_data_df, batch_id):
    # good practice to remove possible duplicates within the upload set, unique key identifies a unique review and is set at the top of the notebook
    new_data_df = new_data_df.dropDuplicates(unique_key)
    (delta_df.alias("original")
     .merge(
         new_data_df.alias("new_data"),
         "(original.taster_name = new_data.taster_name AND original.title = new_data.title)"
     )
     .whenMatchedUpdateAll()
     .whenNotMatchedInsertAll()
     .execute()
    )

# %%
dfn = spark.read.csv(header=True, path='../rawdata/wine/wineupdate.csv', inferSchema=True)
dfn.select(unique_key + ['points']).toPandas().head(4)
# Out:
#          taster_name                                              title  \
# 0      Kerin O’Keefe                    Cormòns 2014 Sauvignon (Collio)
# 1         Roger Voss  Pierre Morey 2005 Santenots Premier Cru  (Volnay)
# 2  Michael Schachner  Pedro Escudero 2012 Fuente Elvira Verdejo (Rueda)
# 3      Kerin O’Keefe  Poggio al Chiuso 2014 Voltaccia 49 Merlot (Tos...
#
#    points
# 0      83
# 1      81
# 2      35
# 3      53

# %%
dfn.count()
# Out:
# 100

# %%
# now we replace the streamQuery with a new component
saveloc = sink_path
streamQuery = (data
              .writeStream
              .format('delta')
              .option('checkpointLocation', f"{saveloc}/_checkpoint")
              .foreachBatch(merge_function)
              .trigger(once=True)
              .start(saveloc)
              )

# %%
streamQuery.recentProgress
# Out:
# [{'id': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e',
#   'runId': 'd50c4b13-4087-4593-be0e-eccb595d787d',
#   'name': None,
#   'timestamp': '2021-11-10T18:28:04.108Z',
#   'batchId': 2,
#   'numInputRows': 200,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 3.8220455587830604,
#   'durationMs': {'addBatch': 49785,
#    'getBatch': 15,
#    'latestOffset': 746,
#    'queryPlanning': 10,
#    'triggerExecution': 52328,
#    'walCommit': 693},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/C:/Spark/rawdata/wine/wine_source]',
#     'startOffset': {'logOffset': 1},
#     'endOffset': {'logOffset': 2},
#     'numInputRows': 200,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 3.8220455587830604}],
#   'sink': {'description': 'ForeachBatchSink', 'numOutputRows': -1}}]

# %%
history = delta_df.history().take(5)
for row in history:
    print(row)
# Out:
# Row(version=2, timestamp=datetime.datetime(2021, 11, 10, 19, 28, 51, 705000), userId=None, userName=None, operation='MERGE', operationParameters={'matchedPredicates': '[{"actionType":"update"}]', 'predicate': '((original.`taster_name` = new_data.`taster_name`) AND (original.`title` = new_data.`title`))', 'notMatchedPredicates': '[{"actionType":"insert"}]'}, job=None, notebook=None, clusterId=None, readVersion=1, isolationLevel=None, isBlindAppend=False, operationMetrics={'numOutputRows': '118971', 'numTargetRowsInserted': '2', 'numTargetRowsUpdated': '99', 'numTargetFilesAdded': '200', 'numTargetFilesRemoved': '6', 'numTargetRowsDeleted': '0', 'scanTimeMs': '6767', 'numSourceRows': '100', 'executionTimeMs': '45531', 'numTargetRowsCopied': '118870', 'rewriteTimeMs': '38757'}, userMetadata=None)
# Row(version=1, timestamp=datetime.datetime(2021, 11, 10, 19, 26, 51, 570000), userId=None, userName=None, operation='STREAMING UPDATE', operationParameters={'epochId': '1', 'outputMode': 'Append', 'queryId': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e'}, job=None, notebook=None, clusterId=None, readVersion=0, isolationLevel=None, isBlindAppend=True, operationMetrics={'numOutputRows': '1000', 'numRemovedFiles': '0', 'numAddedFiles': '1', 'numOutputBytes': '61230'}, userMetadata=None)
# Row(version=0, timestamp=datetime.datetime(2021, 11, 10, 19, 25, 58, 639000), userId=None, userName=None, operation='STREAMING UPDATE', operationParameters={'epochId': '0', 'outputMode': 'Append', 'queryId': '224a9794-bf0b-4788-9cfe-86f9e91a8b6e'}, job=None, notebook=None, clusterId=None, readVersion=None, isolationLevel=None, isBlindAppend=True, operationMetrics={'numOutputRows': '117969', 'numRemovedFiles': '0', 'numAddedFiles': '5', 'numOutputBytes': '5298445'}, userMetadata=None)

# %%
df_old = spark.read.format("delta").option("versionAsOf", 1).load(sink_path).toPandas().sort_values(['title'])
df_old['version'] = 1

# %%
df_new = spark.read.format("delta").option("versionAsOf", 2).load(sink_path).toPandas().sort_values(['title'])
df_new['version'] = 2

# %%
import pandas as pd
dfconcat = pd.concat([df_old, df_new]).drop_duplicates(['title', 'taster_name', 'version'])
compare = dfconcat.set_index(['title', 'taster_name', 'version']).unstack(2)
compare[compare[('points', 1)] != compare[('points', 2)]]
# Out:
#                                                                         country  \
# version                                                                       1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW     Austria
# Albert Bichot 2010  Bourgogne                      Roger Voss            France
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner  Argentina
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner      Spain
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt              US
# ...                                                                         ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe          Italy
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe          Italy
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner        NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW      France
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan          US
#
#                                                                                  \
# version                                                                       2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW     Austria
# Albert Bichot 2010  Bourgogne                      Roger Voss            France
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner  Argentina
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner      Spain
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt              US
# ...                                                                         ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe          Italy
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe          Italy
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner  Argentina
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW      France
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan          US
#
#                                                                      points  \
# version                                                                   1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW    92.0
# Albert Bichot 2010  Bourgogne                      Roger Voss          85.0
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner   85.0
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner   88.0
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt        87.0
# ...                                                                     ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe       93.0
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe       91.0
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner    NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW    88.0
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan    88.0
#
#                                                                             \
# version                                                                  2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW   44.0
# Albert Bichot 2010  Bourgogne                      Roger Voss          1.0
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner  58.0
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner  16.0
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt       81.0
# ...                                                                    ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe      57.0
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe      26.0
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner  21.0
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW   35.0
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan   51.0
#
#                                                                      price  \
# version                                                                  1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW    NaN
# Albert Bichot 2010  Bourgogne                      Roger Voss         16.0
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner  10.0
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner  22.0
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt       22.0
# ...                                                                    ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe      23.0
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe      45.0
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner   NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW   15.0
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan   16.0
#
#                                                                             \
# version                                                                  2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW    NaN
# Albert Bichot 2010  Bourgogne                      Roger Voss         16.0
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner  10.0
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner  22.0
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt       22.0
# ...                                                                    ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe      23.0
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe      45.0
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner  46.0
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW   15.0
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan   16.0
#
#                                                                                province  \
# version                                                                               1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW            Kremstal
# Albert Bichot 2010  Bourgogne                      Roger Voss                  Burgundy
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner   Mendoza Province
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner          Catalonia
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt                  Oregon
# ...                                                                                 ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe      Sicily & Sardinia
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                 Veneto
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner                NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW              Alsace
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan          Washington
#
#                                                                                          \
# version                                                                               2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW            Kremstal
# Albert Bichot 2010  Bourgogne                      Roger Voss                  Burgundy
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner   Mendoza Province
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner          Catalonia
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt                  Oregon
# ...                                                                                 ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe      Sicily & Sardinia
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                 Veneto
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner   Mendoza Province
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW              Alsace
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan          Washington
#
#                                                                                                  region_1  \
# version                                                                                                 1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW                                  None
# Albert Bichot 2010  Bourgogne                      Roger Voss                                   Bourgogne
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner                              Mendoza
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner                                 Cava
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt                        Chehalem Mountains
# ...                                                                                                   ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe                    Vermentino di Gallura
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe      Valdobbiadene Superiore di Cartizze
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner                                  NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW                                Alsace
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan                         Yakima Valley
#
#                                                                                                            \
# version                                                                                                 2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW                                  None
# Albert Bichot 2010  Bourgogne                      Roger Voss                                   Bourgogne
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner                              Mendoza
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner                                 Cava
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt                        Chehalem Mountains
# ...                                                                                                   ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe                    Vermentino di Gallura
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe      Valdobbiadene Superiore di Cartizze
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner                             Perdriel
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW                                Alsace
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan                         Yakima Valley
#
#                                                                                region_2  \
# version                                                                               1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW                None
# Albert Bichot 2010  Bourgogne                      Roger Voss                      None
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner               None
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner               None
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt       Willamette Valley
# ...                                                                                 ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe                   None
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                   None
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner                NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW                None
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan     Columbia Valley
#
#                                                                                          \
# version                                                                               2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW                None
# Albert Bichot 2010  Bourgogne                      Roger Voss                      None
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner               None
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner               None
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt       Willamette Valley
# ...                                                                                 ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe                   None
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                   None
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner               None
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW                None
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan     Columbia Valley
#
#                                                                      taster_twitter_handle  \
# version                                                                                  1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW            @AnneInVino
# Albert Bichot 2010  Bourgogne                      Roger Voss                   @vossroger
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner           @wineschach
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner           @wineschach
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt                @paulgwine
# ...                                                                                    ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe              @kerinokeefe
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe              @kerinokeefe
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner                   NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW            @AnneInVino
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan          @wawinereport
#
#                                                                                      \
# version                                                                           2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW     @AnneInVino
# Albert Bichot 2010  Bourgogne                      Roger Voss            @vossroger
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner    @wineschach
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner    @wineschach
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt         @paulgwine
# ...                                                                             ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe       @kerinokeefe
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe       @kerinokeefe
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner    @wineschach
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW     @AnneInVino
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan   @wawinereport
#
#                                                                               variety  \
# version                                                                             1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW          Riesling
# Albert Bichot 2010  Bourgogne                      Roger Voss              Chardonnay
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner           Malbec
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner  Sparkling Blend
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt            Chardonnay
# ...                                                                               ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe           Vermentino
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                Glera
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner              NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW    Gewürztraminer
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan      Pinot Grigio
#
#                                                                                        \
# version                                                                             2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW          Riesling
# Albert Bichot 2010  Bourgogne                      Roger Voss              Chardonnay
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner           Malbec
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner  Sparkling Blend
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt            Chardonnay
# ...                                                                               ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe           Vermentino
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe                Glera
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner       Chardonnay
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW    Gewürztraminer
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan      Pinot Grigio
#
#                                                                              winery  \
# version                                                                           1
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW          Aigner
# Albert Bichot 2010  Bourgogne                      Roger Voss         Albert Bichot
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner   Alma del Sur
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner    Alta Alella
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt           Anam Cara
# ...                                                                             ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe       Vigne Surrau
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe        Villa Sandi
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner            NaN
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW           Willm
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan       Wind Rose
#
#
# version                                                                           2
# title                                              taster_name
# Aigner 2015 Weinzierlberg Riesling (Kremstal)      Anne Krebiehl MW          Aigner
# Albert Bichot 2010  Bourgogne                      Roger Voss         Albert Bichot
# Alma del Sur 2011 Colección Malbec (Mendoza)       Michael Schachner   Alma del Sur
# Alta Alella 2014 Reserva Brut Nature Sparkling ... Michael Schachner    Alta Alella
# Anam Cara 2014 Nicholas Estate Chardonnay (Cheh... Paul Gregutt           Anam Cara
# ...                                                                             ...
# Vigne Surrau 2014 Sciala Superiore  (Vermentino... Kerin O’Keefe       Vigne Surrau
# Villa Sandi 2015 Cartizze Vigna La Rivetta  (Va... Kerin O’Keefe        Villa Sandi
# Viña Cobos 2015 Bramare Marchiori Vineyard Char... Michael Schachner     Viña Cobos
# Willm 2015 Réserve Gewurztraminer (Alsace)         Anne Krebiehl MW           Willm
# Wind Rose 2015 Dry White Wine Pinot Grigio (Yak... Sean P. Sullivan       Wind Rose
#
# [100 rows x 18 columns]

# %%
title = 'Willm 2015 Réserve Gewurztraminer (Alsace)'
taster_name = 'Anne Krebiehl\xa0MW'

# %%
df_old[(df_old.taster_name==taster_name) & (df_old.title==title)]
#df_old[df_old.title==title].taster_name.values
# Out:
#       country  points  price province region_1 region_2       taster_name  \
# 15613  France      88   15.0   Alsace   Alsace     None  Anne Krebiehl MW
#
#       taster_twitter_handle                                       title  \
# 15613           @AnneInVino  Willm 2015 Réserve Gewurztraminer (Alsace)
#
#               variety winery  version
# 15613  Gewürztraminer  Willm        1

# %%
df_new[(df_new.taster_name==taster_name) & (df_new.title==title)]
# Out:
#       country  points  price province region_1 region_2       taster_name  \
# 90164  France      35   15.0   Alsace   Alsace     None  Anne Krebiehl MW
#
#       taster_twitter_handle                                       title  \
# 90164           @AnneInVino  Willm 2015 Réserve Gewurztraminer (Alsace)
#
#               variety winery  version
# 90164  Gewürztraminer  Willm        2

# %%
dfconcat[(dfconcat.taster_name==taster_name) & (dfconcat.title==title)]
# Out:
#       country  points  price province region_1 region_2       taster_name  \
# 15613  France      88   15.0   Alsace   Alsace     None  Anne Krebiehl MW
# 90164  France      35   15.0   Alsace   Alsace     None  Anne Krebiehl MW
#
#       taster_twitter_handle                                       title  \
# 15613           @AnneInVino  Willm 2015 Réserve Gewurztraminer (Alsace)
# 90164           @AnneInVino  Willm 2015 Réserve Gewurztraminer (Alsace)
#
#               variety winery  version
# 15613  Gewürztraminer  Willm        1
# 90164  Gewürztraminer  Willm        2

# %% [markdown]
# # Without Spark
#
# As mentioned it is possible now to read delta files in python without using any spark cluster or pyspark code. This is shown below
#
# Writing is currently not possible yet (11-12-2021), for notes and docs see here: https://github.com/delta-io/delta-rs

# %%
from deltalake import DeltaTable
dt = DeltaTable(sink_path)
dt.version()
dt.load_version(0)

# %%
df = dt.to_pyarrow_table().to_pandas()
df
# Out:
#         country  points  price           province           region_1  \
# 0         Italy      88   41.0  Sicily & Sardinia               Etna
# 1            US      88   60.0             Oregon  Willamette Valley
# 2        France      88   26.0   Southwest France          Montravel
# 3        France      88   25.0   Southwest France          Montravel
# 4        France      88   16.0       Loire Valley             Quincy
# ...         ...     ...    ...                ...                ...
# 117964  Germany      90   28.0              Mosel               None
# 117965       US      90   75.0             Oregon             Oregon
# 117966   France      90   30.0             Alsace             Alsace
# 117967   France      90   32.0             Alsace             Alsace
# 117968   France      90   21.0             Alsace             Alsace
#
#                  region_2         taster_name taster_twitter_handle  \
# 0                    None                None                  None
# 1       Willamette Valley        Paul Gregutt           @paulgwine
# 2                    None          Roger Voss            @vossroger
# 3                    None          Roger Voss            @vossroger
# 4                    None          Roger Voss            @vossroger
# ...                   ...                 ...                   ...
# 117964               None  Anna Lee C. Iijima                  None
# 117965       Oregon Other        Paul Gregutt           @paulgwine
# 117966               None          Roger Voss            @vossroger
# 117967               None          Roger Voss            @vossroger
# 117968               None          Roger Voss            @vossroger
#
#                                                     title  \
# 0                     Benanti 2005 Il Monovitigno  (Etna)
# 1       Benton-Lane 2006 First Class Pinot Noir (Willa...
# 2       Château Puy-Servain 2003 Vieilles Vignes  (Mon...
# 3        Château Puy-Servain 2007 Marjolaine  (Montravel)
# 4                   Domaine Philippe Portier 2007  Quincy
# ...                                                   ...
# 117964  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 117965                  Citation 2004 Pinot Noir (Oregon)
# 117966  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 117967      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 117968  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                            variety                                    winery
# 0                Nerello Mascalese                                   Benanti
# 1                       Pinot Noir                               Benton-Lane
# 2         Bordeaux-style Red Blend                       Château Puy-Servain
# 3       Bordeaux-style White Blend                       Château Puy-Servain
# 4                  Sauvignon Blanc                  Domaine Philippe Portier
# ...                            ...                                       ...
# 117964                    Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)
# 117965                  Pinot Noir                                  Citation
# 117966              Gewürztraminer                           Domaine Gresser
# 117967                  Pinot Gris                      Domaine Marcel Deiss
# 117968              Gewürztraminer                          Domaine Schoffit
#
# [117969 rows x 11 columns]
